# %%
import pandas as pd
import numpy as np
from citipy import citipy
import requests 
import time
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#city_weather = requests.get(city_url).json()
#city_weather

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]['description']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san patricio
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | arman
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | mount gambier
# Processing Record 6 of Set 1 | bathsheba
# Processing Record 7 of Set 1 | moiyabana
# City not found. Skipping...
# Processing Record 8 of Set 1 | rosarito
# Processing Record 9 of Set 1 | sao felix do xingu
# Processing Record 10 of Set 1 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | santa quiteria do maranhao
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 1 | pangkalanbuun
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | penzance
# Processing Record 22 of Set 1 | ponta delgada
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | severo-yeniseyskiy
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | trzebiatow
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | fort nelson
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | mehamn
# Processing Record 34 of Set 1 | otradnoye
# Processing Record 35 of Set 1 | kirakira
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | flin flon
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | husavik
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | merauke
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | airai
# Processing Record 48 of Set 1 | guerrero negro
# Processing Record 49 of Set 1 | lakatoro
# Processing Record 50 of Set 1 | vieques
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | dwarka
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | jawa
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | nevel
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | linxia
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | sakakah
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | khakhea
# Processing Record 16 of Set 2 | saint anthony
# Processing Record 17 of Set 2 | isiro
# Processing Record 18 of Set 2 | muroto
# Processing Record 19 of Set 2 | makasar
# Processing Record 20 of Set 2 | zangakatun
# Processing Record 21 of Set 2 | north bend
# Processing Record 22 of Set 2 | kolyvan
# Processing Record 23 of Set 2 | kerrville
# Processing Record 24 of Set 2 | portland
# Processing Record 25 of Set 2 | alice springs
# Processing Record 26 of Set 2 | lukang
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | port hawkesbury
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | san fernando
# Processing Record 31 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | worthington
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | khromtau
# Processing Record 37 of Set 2 | nelson bay
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | alofi
# Processing Record 40 of Set 2 | qinhuangdao
# Processing Record 41 of Set 2 | tazovskiy
# Processing Record 42 of Set 2 | freeport
# Processing Record 43 of Set 2 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 2 | batagay-alyta
# Processing Record 45 of Set 2 | lar gerd
# City not found. Skipping...
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | libreville
# Processing Record 48 of Set 2 | busayra
# Processing Record 49 of Set 2 | clyde river
# Processing Record 50 of Set 2 | codrington
# Processing Record 1 of Set 3 | the valley
# Processing Record 2 of Set 3 | anito
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | naryan-mar
# Processing Record 7 of Set 3 | constitucion
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | leh
# Processing Record 10 of Set 3 | yuryevets
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | ornes
# Processing Record 13 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 3 | bam
# Processing Record 17 of Set 3 | kupang
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | bermeo
# Processing Record 20 of Set 3 | westport
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | hobyo
# Processing Record 23 of Set 3 | denpasar
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | salinopolis
# Processing Record 26 of Set 3 | anadyr
# Processing Record 27 of Set 3 | raudeberg
# Processing Record 28 of Set 3 | souillac
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | awjilah
# Processing Record 33 of Set 3 | turukhansk
# Processing Record 34 of Set 3 | wuchang
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | kapit
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | tabukiniberu
# City not found. Skipping...
# Processing Record 40 of Set 3 | luba
# Processing Record 41 of Set 3 | ribeira grande
# Processing Record 42 of Set 3 | linjiang
# Processing Record 43 of Set 3 | vardo
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | ketchikan
# Processing Record 47 of Set 3 | yulara
# Processing Record 48 of Set 3 | kiunga
# Processing Record 49 of Set 3 | borazjan
# Processing Record 50 of Set 3 | taikang
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | rio gallegos
# Processing Record 6 of Set 4 | shetpe
# Processing Record 7 of Set 4 | altay
# Processing Record 8 of Set 4 | pochutla
# Processing Record 9 of Set 4 | wewak
# Processing Record 10 of Set 4 | marienburg
# Processing Record 11 of Set 4 | san carlos
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | muzhi
# Processing Record 14 of Set 4 | bluefield
# Processing Record 15 of Set 4 | saldanha
# Processing Record 16 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 17 of Set 4 | new norfolk
# Processing Record 18 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 4 | suntar
# Processing Record 20 of Set 4 | lianzhou
# Processing Record 21 of Set 4 | tabriz
# Processing Record 22 of Set 4 | sekoma
# Processing Record 23 of Set 4 | sao joao da barra
# Processing Record 24 of Set 4 | thano bula khan
# City not found. Skipping...
# Processing Record 25 of Set 4 | santa rosa
# Processing Record 26 of Set 4 | cap-aux-meules
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | lobito
# Processing Record 29 of Set 4 | kuliyapitiya
# Processing Record 30 of Set 4 | buluang
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | oktyabrskoye
# Processing Record 33 of Set 4 | lugovskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | waingapu
# Processing Record 35 of Set 4 | am timan
# Processing Record 36 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 4 | havre-saint-pierre
# Processing Record 38 of Set 4 | jamestown
# Processing Record 39 of Set 4 | shingu
# Processing Record 40 of Set 4 | dumas
# Processing Record 41 of Set 4 | kavaratti
# Processing Record 42 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 4 | shirokiy
# Processing Record 44 of Set 4 | half moon bay
# Processing Record 45 of Set 4 | taoudenni
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | batagay
# Processing Record 48 of Set 4 | vreden
# Processing Record 49 of Set 4 | bambous virieux
# Processing Record 50 of Set 4 | laguna
# Processing Record 1 of Set 5 | vostok
# Processing Record 2 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 5 | port-gentil
# Processing Record 4 of Set 5 | comodoro rivadavia
# Processing Record 5 of Set 5 | tiksi
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | nokaneng
# Processing Record 8 of Set 5 | la ronge
# Processing Record 9 of Set 5 | pisco
# Processing Record 10 of Set 5 | soyo
# Processing Record 11 of Set 5 | doha
# Processing Record 12 of Set 5 | cabra
# Processing Record 13 of Set 5 | banda aceh
# Processing Record 14 of Set 5 | tawang
# Processing Record 15 of Set 5 | karwar
# Processing Record 16 of Set 5 | yeniseysk
# Processing Record 17 of Set 5 | iralaya
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | nenjiang
# Processing Record 21 of Set 5 | alcudia
# Processing Record 22 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 5 | namuac
# Processing Record 24 of Set 5 | emerald
# Processing Record 25 of Set 5 | necochea
# Processing Record 26 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 5 | guadalupe y calvo
# Processing Record 28 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 5 | port elizabeth
# Processing Record 30 of Set 5 | vigeland
# Processing Record 31 of Set 5 | kankon
# Processing Record 32 of Set 5 | el jicaro
# Processing Record 33 of Set 5 | asau
# Processing Record 34 of Set 5 | lebork
# Processing Record 35 of Set 5 | charters towers
# Processing Record 36 of Set 5 | bologoye
# Processing Record 37 of Set 5 | zunyi
# Processing Record 38 of Set 5 | general roca
# Processing Record 39 of Set 5 | cockburn town
# Processing Record 40 of Set 5 | hamilton
# Processing Record 41 of Set 5 | palafrugell
# Processing Record 42 of Set 5 | tefe
# Processing Record 43 of Set 5 | jalu
# Processing Record 44 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 45 of Set 5 | along
# Processing Record 46 of Set 5 | avera
# Processing Record 47 of Set 5 | leningradskiy
# Processing Record 48 of Set 5 | port hueneme
# Processing Record 49 of Set 5 | kavieng
# Processing Record 50 of Set 5 | voh
# Processing Record 1 of Set 6 | griffith
# Processing Record 2 of Set 6 | nyurba
# Processing Record 3 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | walvis bay
# Processing Record 6 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 6 | wattegama
# Processing Record 8 of Set 6 | chapais
# Processing Record 9 of Set 6 | north vanlaiphai
# Processing Record 10 of Set 6 | aparecida do taboado
# Processing Record 11 of Set 6 | ibra
# Processing Record 12 of Set 6 | manzhouli
# Processing Record 13 of Set 6 | panguipulli
# Processing Record 14 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 15 of Set 6 | katangli
# Processing Record 16 of Set 6 | kungurtug
# Processing Record 17 of Set 6 | udachnyy
# Processing Record 18 of Set 6 | lebu
# Processing Record 19 of Set 6 | wagar
# Processing Record 20 of Set 6 | tuktoyaktuk
# Processing Record 21 of Set 6 | anuradhapura
# Processing Record 22 of Set 6 | beringovskiy
# Processing Record 23 of Set 6 | hearst
# Processing Record 24 of Set 6 | sitka
# Processing Record 25 of Set 6 | krasnyy
# Processing Record 26 of Set 6 | palasa
# Processing Record 27 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 6 | tapes
# Processing Record 29 of Set 6 | sorland
# Processing Record 30 of Set 6 | pitimbu
# Processing Record 31 of Set 6 | huarmey
# Processing Record 32 of Set 6 | teya
# Processing Record 33 of Set 6 | fuerte olimpo
# Processing Record 34 of Set 6 | kismayo
# Processing Record 35 of Set 6 | dhidhdhoo
# Processing Record 36 of Set 6 | khani
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | gouyave
# Processing Record 39 of Set 6 | narsaq
# Processing Record 40 of Set 6 | guangyuan
# Processing Record 41 of Set 6 | suez
# Processing Record 42 of Set 6 | mbigou
# Processing Record 43 of Set 6 | miraflores
# Processing Record 44 of Set 6 | whitehorse
# Processing Record 45 of Set 6 | la grange
# Processing Record 46 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 47 of Set 6 | lahij
# Processing Record 48 of Set 6 | kargasok
# Processing Record 49 of Set 6 | nisia floresta
# Processing Record 50 of Set 6 | santa marta
# Processing Record 1 of Set 7 | victoria
# Processing Record 2 of Set 7 | grand gaube
# Processing Record 3 of Set 7 | susangerd
# Processing Record 4 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 7 | edd
# Processing Record 6 of Set 7 | luderitz
# Processing Record 7 of Set 7 | baisha
# Processing Record 8 of Set 7 | hasaki
# Processing Record 9 of Set 7 | olinda
# Processing Record 10 of Set 7 | guayaramerin
# Processing Record 11 of Set 7 | caraquet
# Processing Record 12 of Set 7 | veraval
# Processing Record 13 of Set 7 | ust-kuyga
# Processing Record 14 of Set 7 | sug-aksy
# City not found. Skipping...
# Processing Record 15 of Set 7 | kaitangata
# Processing Record 16 of Set 7 | faanui
# Processing Record 17 of Set 7 | cabedelo
# Processing Record 18 of Set 7 | santa rosa del sur
# Processing Record 19 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 20 of Set 7 | pueblo nuevo
# Processing Record 21 of Set 7 | san carlos de bariloche
# Processing Record 22 of Set 7 | madera
# Processing Record 23 of Set 7 | longyearbyen
# Processing Record 24 of Set 7 | amga
# Processing Record 25 of Set 7 | sur
# Processing Record 26 of Set 7 | le port
# Processing Record 27 of Set 7 | kaka
# Processing Record 28 of Set 7 | ewa beach
# Processing Record 29 of Set 7 | saint-joseph
# Processing Record 30 of Set 7 | vila
# Processing Record 31 of Set 7 | axim
# Processing Record 32 of Set 7 | la orilla
# Processing Record 33 of Set 7 | susanville
# Processing Record 34 of Set 7 | marawi
# Processing Record 35 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 36 of Set 7 | puerto quijarro
# Processing Record 37 of Set 7 | pizarro
# Processing Record 38 of Set 7 | shubarkuduk
# Processing Record 39 of Set 7 | poum
# Processing Record 40 of Set 7 | sao filipe
# Processing Record 41 of Set 7 | sarakhs
# Processing Record 42 of Set 7 | batemans bay
# Processing Record 43 of Set 7 | richards bay
# Processing Record 44 of Set 7 | katsuura
# Processing Record 45 of Set 7 | slave lake
# Processing Record 46 of Set 7 | reconquista
# Processing Record 47 of Set 7 | gamba
# Processing Record 48 of Set 7 | chifeng
# Processing Record 49 of Set 7 | marrakesh
# Processing Record 50 of Set 7 | manggar
# Processing Record 1 of Set 8 | harbour breton
# Processing Record 2 of Set 8 | bandarbeyla
# Processing Record 3 of Set 8 | krasnoselkup
# Processing Record 4 of Set 8 | zhigansk
# Processing Record 5 of Set 8 | northam
# Processing Record 6 of Set 8 | tucurui
# Processing Record 7 of Set 8 | antalaha
# Processing Record 8 of Set 8 | pomorie
# Processing Record 9 of Set 8 | tura
# Processing Record 10 of Set 8 | helong
# Processing Record 11 of Set 8 | talnakh
# Processing Record 12 of Set 8 | nioro
# Processing Record 13 of Set 8 | ilhabela
# Processing Record 14 of Set 8 | lakes entrance
# Processing Record 15 of Set 8 | cabo rojo
# Processing Record 16 of Set 8 | krasnaya gora
# Processing Record 17 of Set 8 | pousat
# City not found. Skipping...
# Processing Record 18 of Set 8 | namwala
# Processing Record 19 of Set 8 | samur
# Processing Record 20 of Set 8 | nabire
# Processing Record 21 of Set 8 | lata
# Processing Record 22 of Set 8 | puerto el triunfo
# Processing Record 23 of Set 8 | kahului
# Processing Record 24 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 8 | talakan
# Processing Record 26 of Set 8 | karratha
# Processing Record 27 of Set 8 | havelock
# Processing Record 28 of Set 8 | guhagar
# Processing Record 29 of Set 8 | cooma
# Processing Record 30 of Set 8 | bemidji
# Processing Record 31 of Set 8 | ngaoundere
# Processing Record 32 of Set 8 | black river
# Processing Record 33 of Set 8 | okha
# Processing Record 34 of Set 8 | beirut
# Processing Record 35 of Set 8 | curuca
# Processing Record 36 of Set 8 | sao gabriel da cachoeira
# Processing Record 37 of Set 8 | cherskiy
# Processing Record 38 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 39 of Set 8 | honiara
# Processing Record 40 of Set 8 | broome
# Processing Record 41 of Set 8 | birin
# Processing Record 42 of Set 8 | tongliao
# Processing Record 43 of Set 8 | chernyshevskiy
# Processing Record 44 of Set 8 | goderich
# Processing Record 45 of Set 8 | wasilla
# Processing Record 46 of Set 8 | diego de almagro
# Processing Record 47 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 8 | portales
# Processing Record 49 of Set 8 | kyle
# Processing Record 50 of Set 8 | austin
# Processing Record 1 of Set 9 | coahuayana
# Processing Record 2 of Set 9 | quipile
# Processing Record 3 of Set 9 | awbari
# Processing Record 4 of Set 9 | tucumcari
# Processing Record 5 of Set 9 | miracema do tocantins
# Processing Record 6 of Set 9 | santa isabel do rio negro
# Processing Record 7 of Set 9 | korla
# Processing Record 8 of Set 9 | fairbanks
# Processing Record 9 of Set 9 | pozega
# Processing Record 10 of Set 9 | bonoua
# Processing Record 11 of Set 9 | mandera
# Processing Record 12 of Set 9 | palmer
# Processing Record 13 of Set 9 | qinzhou
# Processing Record 14 of Set 9 | manjeshwar
# Processing Record 15 of Set 9 | conceicao do araguaia
# Processing Record 16 of Set 9 | grindavik
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | salalah
# Processing Record 19 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 9 | college
# Processing Record 22 of Set 9 | dasoguz
# Processing Record 23 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 24 of Set 9 | padang
# Processing Record 25 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 26 of Set 9 | rivadavia
# Processing Record 27 of Set 9 | byron bay
# Processing Record 28 of Set 9 | camana
# Processing Record 29 of Set 9 | porbandar
# Processing Record 30 of Set 9 | naze
# Processing Record 31 of Set 9 | pangody
# Processing Record 32 of Set 9 | bengkulu
# Processing Record 33 of Set 9 | erenhot
# Processing Record 34 of Set 9 | vila velha
# Processing Record 35 of Set 9 | soe
# Processing Record 36 of Set 9 | la asuncion
# Processing Record 37 of Set 9 | saint john
# Processing Record 38 of Set 9 | ahipara
# Processing Record 39 of Set 9 | rolla
# Processing Record 40 of Set 9 | chicama
# Processing Record 41 of Set 9 | west bay
# Processing Record 42 of Set 9 | la seyne-sur-mer
# Processing Record 43 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 9 | mayo
# Processing Record 45 of Set 9 | agadez
# Processing Record 46 of Set 9 | manga
# Processing Record 47 of Set 9 | virginia beach
# Processing Record 48 of Set 9 | nishihara
# Processing Record 49 of Set 9 | leninskoye
# Processing Record 50 of Set 9 | port blair
# Processing Record 1 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 10 | mount isa
# Processing Record 3 of Set 10 | sombrerete
# Processing Record 4 of Set 10 | grajau
# Processing Record 5 of Set 10 | boksitogorsk
# Processing Record 6 of Set 10 | pocosol
# Processing Record 7 of Set 10 | mumford
# Processing Record 8 of Set 10 | jinka
# Processing Record 9 of Set 10 | minbu
# Processing Record 10 of Set 10 | majalgaon
# Processing Record 11 of Set 10 | bosansko grahovo
# Processing Record 12 of Set 10 | novopokrovka
# Processing Record 13 of Set 10 | road town
# Processing Record 14 of Set 10 | sena madureira
# Processing Record 15 of Set 10 | puerto penasco
# Processing Record 16 of Set 10 | san rafael
# Processing Record 17 of Set 10 | fujin
# Processing Record 18 of Set 10 | saint-louis
# Processing Record 19 of Set 10 | cangzhou
# Processing Record 20 of Set 10 | toora-khem
# Processing Record 21 of Set 10 | klyuchi
# Processing Record 22 of Set 10 | xiamen
# Processing Record 23 of Set 10 | quelimane
# Processing Record 24 of Set 10 | villa rica
# Processing Record 25 of Set 10 | fengrun
# Processing Record 26 of Set 10 | hofn
# Processing Record 27 of Set 10 | abay
# Processing Record 28 of Set 10 | carauari
# Processing Record 29 of Set 10 | hambantota
# Processing Record 30 of Set 10 | kinango
# Processing Record 31 of Set 10 | calabozo
# Processing Record 32 of Set 10 | kondinskoye
# Processing Record 33 of Set 10 | cortez
# Processing Record 34 of Set 10 | itoman
# Processing Record 35 of Set 10 | portree
# Processing Record 36 of Set 10 | los llanos de aridane
# Processing Record 37 of Set 10 | carutapera
# Processing Record 38 of Set 10 | abu samrah
# Processing Record 39 of Set 10 | kisangani
# Processing Record 40 of Set 10 | touros
# Processing Record 41 of Set 10 | fenyi
# Processing Record 42 of Set 10 | ostersund
# Processing Record 43 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 10 | tynda
# Processing Record 45 of Set 10 | asyut
# Processing Record 46 of Set 10 | tuzha
# Processing Record 47 of Set 10 | poya
# Processing Record 48 of Set 10 | hualmay
# Processing Record 49 of Set 10 | vaitape
# Processing Record 50 of Set 10 | orong
# Processing Record 1 of Set 11 | chumikan
# Processing Record 2 of Set 11 | porosozero
# Processing Record 3 of Set 11 | harlingen
# Processing Record 4 of Set 11 | kisanga
# Processing Record 5 of Set 11 | grand-santi
# Processing Record 6 of Set 11 | mecca
# Processing Record 7 of Set 11 | morant bay
# Processing Record 8 of Set 11 | durazno
# Processing Record 9 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 11 | payyannur
# Processing Record 11 of Set 11 | terrace
# Processing Record 12 of Set 11 | matay
# Processing Record 13 of Set 11 | sandwick
# Processing Record 14 of Set 11 | nizhnyaya tavda
# Processing Record 15 of Set 11 | coquimbo
# Processing Record 16 of Set 11 | lianran
# Processing Record 17 of Set 11 | sarankhola
# Processing Record 18 of Set 11 | chunskiy
# Processing Record 19 of Set 11 | kangaatsiaq
# Processing Record 20 of Set 11 | takaka
# Processing Record 21 of Set 11 | bulungu
# Processing Record 22 of Set 11 | fushe-kruje
# Processing Record 23 of Set 11 | carmelo
# Processing Record 24 of Set 11 | namibe
# Processing Record 25 of Set 11 | galle
# Processing Record 26 of Set 11 | estacion coahuila
# Processing Record 27 of Set 11 | coihaique
# Processing Record 28 of Set 11 | vao
# Processing Record 29 of Set 11 | kieta
# Processing Record 30 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 11 | kolokani
# Processing Record 32 of Set 11 | faya
# Processing Record 33 of Set 11 | askarovo
# Processing Record 34 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 11 | carballo
# Processing Record 36 of Set 11 | guymon
# Processing Record 37 of Set 11 | ati
# Processing Record 38 of Set 11 | sabha
# Processing Record 39 of Set 11 | aviles
# Processing Record 40 of Set 11 | klaksvik
# Processing Record 41 of Set 11 | bassum
# Processing Record 42 of Set 11 | khasan
# Processing Record 43 of Set 11 | hamada
# Processing Record 44 of Set 11 | quang ngai
# Processing Record 45 of Set 11 | caraballeda
# Processing Record 46 of Set 11 | kalmunai
# Processing Record 47 of Set 11 | yenagoa
# Processing Record 48 of Set 11 | pangnirtung
# Processing Record 49 of Set 11 | mapiripan
# Processing Record 50 of Set 11 | santa cruz
# Processing Record 1 of Set 12 | la maddalena
# Processing Record 2 of Set 12 | jieshi
# Processing Record 3 of Set 12 | yakeshi
# Processing Record 4 of Set 12 | san giustino
# Processing Record 5 of Set 12 | berlevag
# Processing Record 6 of Set 12 | lethem
# Processing Record 7 of Set 12 | hirara
# Processing Record 8 of Set 12 | luangwa
# Processing Record 9 of Set 12 | winnemucca
# Processing Record 10 of Set 12 | tres arroyos
# Processing Record 11 of Set 12 | chimbote
# Processing Record 12 of Set 12 | punta alta
# Processing Record 13 of Set 12 | russell
# Processing Record 14 of Set 12 | yong peng
# Processing Record 15 of Set 12 | quatre cocos
# Processing Record 16 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 12 | gravelbourg
# Processing Record 18 of Set 12 | ulkan
# Processing Record 19 of Set 12 | burns lake
# Processing Record 20 of Set 12 | vieste
# Processing Record 21 of Set 12 | nhulunbuy
# Processing Record 22 of Set 12 | lompoc
# Processing Record 23 of Set 12 | cururupu
# Processing Record 24 of Set 12 | darhan
# Processing Record 25 of Set 12 | kloulklubed
# Processing Record 26 of Set 12 | kamenka
# Processing Record 27 of Set 12 | brainerd
# Processing Record 28 of Set 12 | roma
# Processing Record 29 of Set 12 | srednekolymsk
# Processing Record 30 of Set 12 | decatur
# Processing Record 31 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 12 | goya
# Processing Record 33 of Set 12 | cedar city
# Processing Record 34 of Set 12 | acapulco
# Processing Record 35 of Set 12 | llangefni
# Processing Record 36 of Set 12 | peleduy
# Processing Record 37 of Set 12 | grimmen
# Processing Record 38 of Set 12 | lasa
# Processing Record 39 of Set 12 | kadaya
# Processing Record 40 of Set 12 | perene
# Processing Record 41 of Set 12 | naqadeh
# Processing Record 42 of Set 12 | boyolangu
# Processing Record 43 of Set 12 | lorengau
# Processing Record 44 of Set 12 | egvekinot
# Processing Record 45 of Set 12 | baoqing
# Processing Record 46 of Set 12 | haradok
# Processing Record 47 of Set 12 | maraa
# Processing Record 48 of Set 12 | llandrindod wells
# Processing Record 49 of Set 12 | taksimo
# Processing Record 50 of Set 12 | oranjemund
# Processing Record 1 of Set 13 | prince george
# Processing Record 2 of Set 13 | wilmington
# Processing Record 3 of Set 13 | remontnoye
# Processing Record 4 of Set 13 | synya
# Processing Record 5 of Set 13 | bokovskaya
# Processing Record 6 of Set 13 | bin qirdan
# Processing Record 7 of Set 13 | custodia
# Processing Record 8 of Set 13 | zyryanka
# Processing Record 9 of Set 13 | micheweni
# Processing Record 10 of Set 13 | longyan
# Processing Record 11 of Set 13 | novska
# Processing Record 12 of Set 13 | gizo
# Processing Record 13 of Set 13 | kendari
# Processing Record 14 of Set 13 | collie
# Processing Record 15 of Set 13 | iwanai
# Processing Record 16 of Set 13 | mangrol
# Processing Record 17 of Set 13 | bloomfield
# Processing Record 18 of Set 13 | kruisfontein
# Processing Record 19 of Set 13 | vanimo
# Processing Record 20 of Set 13 | kununurra
# Processing Record 21 of Set 13 | barao de melgaco
# Processing Record 22 of Set 13 | barrhead
# Processing Record 23 of Set 13 | harnoli
# Processing Record 24 of Set 13 | rio grande
# Processing Record 25 of Set 13 | harper
# Processing Record 26 of Set 13 | boa vista
# Processing Record 27 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 13 | talara
# Processing Record 29 of Set 13 | swidwin
# Processing Record 30 of Set 13 | svetlogorsk
# Processing Record 31 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 13 | keskin
# Processing Record 33 of Set 13 | pathein
# Processing Record 34 of Set 13 | amapa
# Processing Record 35 of Set 13 | langsa
# Processing Record 36 of Set 13 | gat
# Processing Record 37 of Set 13 | tyup
# Processing Record 38 of Set 13 | san cristobal
# Processing Record 39 of Set 13 | novyy urgal
# Processing Record 40 of Set 13 | leeton
# Processing Record 41 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 13 | tehri
# Processing Record 43 of Set 13 | yumen
# Processing Record 44 of Set 13 | cam ranh
# Processing Record 45 of Set 13 | ondjiva
# Processing Record 46 of Set 13 | lubango
# Processing Record 47 of Set 13 | norman wells
# Processing Record 48 of Set 13 | burleson
# Processing Record 49 of Set 13 | iqaluit
# Processing Record 50 of Set 13 | pijijiapan
# Processing Record 1 of Set 14 | monrovia
# Processing Record 2 of Set 14 | perth
# Processing Record 3 of Set 14 | qiongshan
# Processing Record 4 of Set 14 | zaritap
# Processing Record 5 of Set 14 | bojonegoro
# Processing Record 6 of Set 14 | angoche
# Processing Record 7 of Set 14 | port macquarie
# Processing Record 8 of Set 14 | astana
# Processing Record 9 of Set 14 | trat
# Processing Record 10 of Set 14 | caravelas
# Processing Record 11 of Set 14 | urumqi
# Processing Record 12 of Set 14 | saint-pierre
# Processing Record 13 of Set 14 | cottonwood
# Processing Record 14 of Set 14 | nome
# Processing Record 15 of Set 14 | sao geraldo do araguaia
# Processing Record 16 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 14 | mwinilunga
# Processing Record 18 of Set 14 | opuwo
# Processing Record 19 of Set 14 | lavrentiya
# Processing Record 20 of Set 14 | vanavara
# Processing Record 21 of Set 14 | bonthe
# Processing Record 22 of Set 14 | ishigaki
# Processing Record 23 of Set 14 | bira
# Processing Record 24 of Set 14 | ryotsu
# Processing Record 25 of Set 14 | riyadh
# Processing Record 26 of Set 14 | tautira
# Processing Record 27 of Set 14 | tabas
# Processing Record 28 of Set 14 | san vicente
# Processing Record 29 of Set 14 | sechura
# Processing Record 30 of Set 14 | novodugino
# Processing Record 31 of Set 14 | jefferson city
# Processing Record 32 of Set 14 | panaba
# Processing Record 33 of Set 14 | kichera
# Processing Record 34 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 35 of Set 14 | aswan
# Processing Record 36 of Set 14 | nizhniy kuranakh
# Processing Record 37 of Set 14 | charlottesville
# Processing Record 38 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 39 of Set 14 | aleksandrovskiy zavod
# Processing Record 40 of Set 14 | vestmanna
# Processing Record 41 of Set 14 | bage
# Processing Record 42 of Set 14 | glenwood springs
# Processing Record 43 of Set 14 | esperance
# Processing Record 44 of Set 14 | iquitos
# Processing Record 45 of Set 14 | nouadhibou
# Processing Record 46 of Set 14 | port angeles
# Processing Record 47 of Set 14 | aktash
# Processing Record 48 of Set 14 | itacarambi
# Processing Record 49 of Set 14 | viedma
# Processing Record 50 of Set 14 | lafia
# Processing Record 1 of Set 15 | khash
# Processing Record 2 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 15 | florence
# Processing Record 4 of Set 15 | karla
# Processing Record 5 of Set 15 | ust-nera
# Processing Record 6 of Set 15 | beberibe
# Processing Record 7 of Set 15 | oil city
# Processing Record 8 of Set 15 | chernyakhovsk
# Processing Record 9 of Set 15 | krapivinskiy
# Processing Record 10 of Set 15 | ushtobe
# Processing Record 11 of Set 15 | locri
# Processing Record 12 of Set 15 | bandar
# Processing Record 13 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 15 | lagos
# Processing Record 15 of Set 15 | raul soares
# Processing Record 16 of Set 15 | seymchan
# Processing Record 17 of Set 15 | yerbogachen
# Processing Record 18 of Set 15 | bayshore gardens
# Processing Record 19 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 20 of Set 15 | jardim
# Processing Record 21 of Set 15 | meulaboh
# Processing Record 22 of Set 15 | yar-sale
# Processing Record 23 of Set 15 | muros
# Processing Record 24 of Set 15 | parabel
# Processing Record 25 of Set 15 | santa margherita ligure
# Processing Record 26 of Set 15 | pavlodar
# Processing Record 27 of Set 15 | yaan
# Processing Record 28 of Set 15 | malacacheta
# Processing Record 29 of Set 15 | natal
# Processing Record 30 of Set 15 | takoradi
# Processing Record 31 of Set 15 | brilon
# Processing Record 32 of Set 15 | evensk
# Processing Record 33 of Set 15 | plettenberg bay
# Processing Record 34 of Set 15 | nemuro
# Processing Record 35 of Set 15 | ulaangom
# Processing Record 36 of Set 15 | turka
# Processing Record 37 of Set 15 | kadiri
# Processing Record 38 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 15 | dharchula
# Processing Record 40 of Set 15 | dunedin
# Processing Record 41 of Set 15 | hannan
# Processing Record 42 of Set 15 | altagracia de orituco
# Processing Record 43 of Set 15 | nalut
# Processing Record 44 of Set 15 | galveston
# Processing Record 45 of Set 15 | pueblo
# Processing Record 46 of Set 15 | ossora
# Processing Record 47 of Set 15 | waw
# Processing Record 48 of Set 15 | santa pola
# Processing Record 49 of Set 15 | los lunas
# Processing Record 50 of Set 15 | kamaishi
# Processing Record 1 of Set 16 | tommot
# Processing Record 2 of Set 16 | qasigiannguit
# Processing Record 3 of Set 16 | beni suef
# Processing Record 4 of Set 16 | usinsk
# Processing Record 5 of Set 16 | jiayuguan
# Processing Record 6 of Set 16 | nouakchott
# Processing Record 7 of Set 16 | mackay
# Processing Record 8 of Set 16 | japura
# Processing Record 9 of Set 16 | aden
# Processing Record 10 of Set 16 | litovko
# Processing Record 11 of Set 16 | ostrovnoy
# Processing Record 12 of Set 16 | paragominas
# Processing Record 13 of Set 16 | port-de-paix
# City not found. Skipping...
# Processing Record 14 of Set 16 | skibbereen
# Processing Record 15 of Set 16 | bilibino
# Processing Record 16 of Set 16 | dalinghe
# City not found. Skipping...
# Processing Record 17 of Set 16 | neryungri
# Processing Record 18 of Set 16 | lakselv
# Processing Record 19 of Set 16 | gimli
# Processing Record 20 of Set 16 | arvika
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
new_order = ['City','Country', 'Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
weatherpy_db = weatherpy_db[new_order]

# %%
weatherpy_db.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0        San Patricio      US  28.0170  -97.5169     82.81        53
# 1             Rikitea      PF -23.1203 -134.9692     76.33        70
# 2               Arman      RU  59.7000  150.1667      5.02        88
# 3         East London      ZA -33.0153   27.9116     69.42        88
# 4       Mount Gambier      AU -37.8333  140.7667     58.91        88
# 5           Bathsheba      BB  13.2167  -59.5167     83.01        74
# 6            Rosarito      MX  32.3333 -117.0333     89.40        51
# 7  Sao Felix Do Xingu      BR  -6.6447  -51.9950     74.57        94
# 8           Ilulissat      GL  69.2167  -51.1000     31.78        90
# 9             Qaanaaq      GL  77.4840  -69.3632      4.80        78
#
#    Cloudiness  Wind Speed Current Description
# 0          97        2.55     overcast clouds
# 1           0       17.20           clear sky
# 2         100       19.46          light snow
# 3          90       11.86          light rain
# 4          90       10.36     overcast clouds
# 5          20       19.57          few clouds
# 6          55        5.57       broken clouds
# 7          97        1.63       moderate rain
# 8         100       10.74                snow
# 9          18        4.29          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WheatherPy_Database.csv"
# Export the City_Data into a CSV.
weatherpy_db.to_csv(output_data_file, index_label="City_ID")
